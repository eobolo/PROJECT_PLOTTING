# %% [markdown]
# # **Project Plotting - Matplotlib Seaborn, Histograms and Boxplots**
#
# The most recent ASC23 considered four major systems-based tracks with a view to providing region-focused contributions to inform the global stocktake among them Cities, urban and rural settlements, infrastructure, and transport.
#
# In this assignment, you will be performing analysis more specifically on transport (vehicles and fuel efficiency).
#
# The dataset has been provided for you.
#
# You are tasked to make sense of this data that will later be used for AI purposes.

# %%
# prerequisite package imports

#YOUR CODE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# :We'll work with the fuel economy dataset in this workspace.
#
# Load the dataset and print at least 10 rows
#
# 1.   Load the dataset
# 2.   print atleast 10 rows of it

# %%
#YOUR CODE
df = pd.read_csv("/content/drive/MyDrive/ALU_MACHINE_LEARNING/fuel_econ.csv")
df.head(10)
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
# 5  32209       Lexus          GS 350  2013     Midsize Cars
# 6  32210       Lexus      GS 350 AWD  2013     Midsize Cars
# 7  32214     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 8  32215     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 9  32216     Hyundai   Genesis Coupe  2013  Subcompact Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# ...

# %% [markdown]
# Play Around with Bin size as you create your Histogram
#
# [Bin size in Matplot Lib](https://www.geeksforgeeks.org/bin-size-in-matplotlib-histogram/)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  **Description**
# The dataset has a number of different statistics that describe fuel efficiency.
#
#
# **TO DO**:
# 1.   create a _histogram_ that depicts the distribution of carbon Dioxide
# 2.   Play  around with different bin width sizes to see what best depicts the data
#
# Create 2 more histograms based on columns of your choice

# %%
co2_data = df["co2"]

# %%
# YOUR CODE HERE
fig, ax = plt.subplots()
ax.hist(co2_data, bins=15, linewidth=0.5, edgecolor="red", color="green")
plt.show()

# %%
fe_data = df["feScore"]

# %%
# YOUR CODE HERE
fig, ax = plt.subplots()
ax.hist(fe_data, bins=10, linewidth=0.5, edgecolor="black")
plt.show()

# %%
pv2_data = df["pv2"]

# %%
# YOUR CODE HERE
fig, ax = plt.subplots()
ax.hist(pv2_data, bins=5, linewidth=0.5, edgecolor="yellow", color="blue")
plt.show()

# %% [markdown]
# ## First Histogram:
#
# This histogram shows a normal distribution. However, the values are shifted towards higher numbers (around 300-500). The bars create a symmetric bell-shaped curve, with the peak around the 300-400 range.
# This histogram indicates that most data points are centered around a higher value compared to the second histogram.
#
# ## Second Histogram:
# Similar to the first one The data follows a roughly normal distribution, peaking around the middle. Most of the values are concentrated between 4 and 6, with fewer values at the extremes.
# This type of histogram is common when the data follows a bell curve, indicating that the majority of the values cluster around a central point, with fewer extreme values.
#
# ## Third Histogram:
# The data is highly skewed to the left, with the majority of values concentrated around a low range (near 0). The bar at this range is significantly taller than the others.
# This suggests that most of the data points are close to 0, with a few points spread out across higher values.

# %% [markdown]
# **TO DO: Write Code that will give you the following plot as below:**
#
# 1.   create a heat map of the data
# 2.Interpret the data - What story does the visualization tell?
#
# >
#
# Finally What Columns would you delete Drop if the target is the ghg score? Justify your Answer
#
#
#
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %%
new_df = pd.DataFrame()
for i in range(df.shape[1]):
  if str(df.iloc[:, i].dtypes) == "object":
    pass
  else:
    new_df[df.iloc[:, i].name] = df.iloc[:, i]
new_df_corr = new_df.corr()
new_df_corr
# Out:
#                  id      year  cylinders     displ       pv2       pv4  \
# id         1.000000  0.985668  -0.060096 -0.074666 -0.006569 -0.021951
# year       0.985668  1.000000  -0.055313 -0.070424  0.006232 -0.033643
# cylinders -0.060096 -0.055313   1.000000  0.933872  0.247571 -0.004264
# displ     -0.074666 -0.070424   0.933872  1.000000  0.259336  0.022072
# pv2       -0.006569  0.006232   0.247571  0.259336  1.000000 -0.665642
# pv4       -0.021951 -0.033643  -0.004264  0.022072 -0.665642  1.000000
# city       0.091800  0.068050  -0.693103 -0.713479 -0.278109  0.035188
# UCity      0.091225  0.066742  -0.666029 -0.686166 -0.272546  0.037869
# highway    0.090593  0.073290  -0.766275 -0.783984 -0.296808  0.074952
# UHighway   0.095359  0.077641  -0.771503 -0.788457 -0.298504  0.077442
# comb       0.093803  0.071993  -0.738023 -0.758397 -0.290883  0.047333
# co2       -0.099717 -0.081165   0.848274  0.855375  0.287200 -0.050153
# ...

# %%
f, ax = plt.subplots(figsize=(12, 10))
heat_map = sns.heatmap(new_df_corr, annot=False)

# %% [markdown]
# Firstly one has to remove colums that are linearly dependent on each other because these columns do not provide more information about this system of equation i.e the matrix so it is more like redundancy in the system
#
# secondly one has to choose columns that have high correlation to the target i.e. ghgScore because we have an probability of predicting the ghgscore if the correct weights and biases are found for that system of equations.
#
# The columns I am going to drop if ghgScore was my target is all columns expect the feScore, and why is that? this is because of those columns are linearly dependent (some of them have a correlation greater than 0.6). a single column is dependent on 6 to 8 other column and based on the system of equations it is redundancy and no new information can be gotten so all columns should be dropped but because the fe2Score has greatest correlation I decided to pick it. I could have picked pv2 or pv4 but they both have low correlation to the target.
